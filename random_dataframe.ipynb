# %%
import pandas as pd
import numpy as np
import random
random.seed(123)

# %% [markdown]
# Notebook for practicing dataframe creation and manipulation

# %%
#create lists for first names, last names, state of residence
#generate random number for age, height, weight

# %%
first_names_source = [
    'Emma', 'Liam', 'Olivia', 'Noah', 'Ava', 'Isabella', 'Sophia', 'Mia', 'Jackson', 'Oliver',
    'Lucas', 'Aiden', 'Layla', 'Ethan', 'Amelia', 'Harper', 'Muhammad', 'Abigail', 'Ella', 'Sofia',
    'Caden', 'Avery', 'Evelyn', 'Ella', 'Aria', 'Grace', 'Riley', 'Chloe', 'Lily', 'Liam',
    'Harper', 'Zoe', 'Luna', 'Mila', 'James', 'Scarlett', 'Mason', 'Emily', 'Lily', 'Aiden',
    'Liam', 'Emma', 'Sophia', 'Mia', 'Noah', 'Olivia', 'Isabella', 'Lucas', 'Ethan', 'James',
    'Avery', 'Ella', 'Riley', 'Layla', 'Scarlett', 'Chloe', 'Liam', 'Oliver', 'Emma', 'Ava',
    'Sophia', 'Isabella', 'Mia', 'Charlotte', 'Amelia', 'Harper', 'Evelyn', 'Abigail', 'Emily',
    'Elizabeth', 'Sofia', 'Avery', 'Ella', 'Scarlett', 'Grace', 'Aubrey', 'Liam', 'Noah', 'Oliver',
    'Ethan', 'Ava', 'Isabella', 'Sophia', 'Mia', 'Amelia', 'Harper', 'Evelyn', 'Liam', 'Noah',
    'Oliver', 'Elijah', 'William', 'James', 'Benjamin', 'Lucas', 'Henry', 'Alexander', 'Sebastian'
]

# %%
last_names_source = [
    'Smith', 'Johnson', 'Williams', 'Jones', 'Brown', 'Davis', 'Miller', 'Wilson', 'Moore', 'Taylor',
    'Anderson', 'Thomas', 'Jackson', 'White', 'Harris', 'Martin', 'Thompson', 'Garcia', 'Martinez', 'Robinson',
    'Clark', 'Rodriguez', 'Lewis', 'Lee', 'Walker', 'Hall', 'Allen', 'Young', 'Hernandez', 'King',
    'Wright', 'Lopez', 'Hill', 'Scott', 'Green', 'Adams', 'Baker', 'Gonzalez', 'Nelson', 'Carter',
    'Mitchell', 'Perez', 'Roberts', 'Turner', 'Phillips', 'Campbell', 'Parker', 'Evans', 'Edwards', 'Collins',
    'Stewart', 'Sanchez', 'Morris', 'Rogers', 'Reed', 'Cook', 'Morgan', 'Bell', 'Murphy', 'Bailey',
    'Cooper', 'Richardson', 'Cox', 'Howard', 'Ward', 'Torres', 'Peterson', 'Gray', 'Ramirez', 'James',
    'Watson', 'Brooks', 'Kelly', 'Sanders', 'Price', 'Bennett', 'Wood', 'Barnes', 'Ross', 'Henderson',
    'Coleman', 'Jenkins', 'Perry', 'Powell', 'Long', 'Patterson', 'Hughes', 'Flores', 'Washington', 'Butler',
    'Simmons', 'Foster', 'Gonzales', 'Bryant', 'Alexander', 'Russell', 'Griffin', 'Diaz', 'Hayes', 'Myers'
]

# %%
state_abbreviations = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA',
    'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD',
    'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ',
    'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC',
    'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'
]

# %%
#generate an entry for a new patient
first_name = random.choice(first_names_source)
last_name = random.choice(last_names_source)
state_of_residence = random.choice(state_abbreviations)

first_name, last_name, state_of_residence
# Out:
# ('Sophia', 'Green', 'CO')

# %%
min_age = 18
max_age = 110

age = random.randint(min_age, max_age)

age
# Out:
# 70

# %%
min_height_inches = 54
max_height_inches = 84

height = random.randint(min_height_inches, max_height_inches)

height
# Out:
# 62

# %%
min_weight_lbs = 100
max_weight_lbs = 350

weight = random.randint(min_weight_lbs, max_weight_lbs)

weight
# Out:
# 127

# %%
#function to generate a new patient to add to the dataframe

def generate_patient_record(first_names_source, last_names_source):
    #set parameters for variables
    min_age = 18
    max_age = 110

    min_height_inches = 54
    max_height_inches = 84

    min_weight_lbs = 100
    max_weight_lbs = 350

    #create a list for a new patient entry
    new_record = [random.choice(first_names_source),
                  random.choice(last_names_source),
                  random.randint(min_age, max_age),
                  random.randint(min_height_inches, max_height_inches),
                  random.randint(min_weight_lbs, max_weight_lbs)
                  ]
    
    return new_record

# %%
#testing function 
patient1 = generate_patient_record(first_names_source, last_names_source)
patient1
# Out:
# ['Ava', 'Edwards', 86, 71, 185]

# %%
#create empty dataframe with appropriate column names

patients_df = pd.DataFrame(columns= ['first_name', 'last_name', 'age', 'height_inches', 'weight_lbs'])

patients_df
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, age, height_inches, weight_lbs]
# Index: []

# %%
# generate a new patient record and append to df

patients_df.loc[len(patients_df)] = patient1

patients_df
# Out:
#   first_name last_name  age  height_inches  weight_lbs
# 0        Ava   Edwards   86             71         185

# %%
# generate list of lists from gene
new_records = []

for i in range(100):
    new_patient = generate_patient_record(first_names_source, last_names_source)
    new_records.append(new_patient)

new_records
# Out:
# [['Mia', 'Miller', 38, 58, 186],
#  ['Avery', 'Roberts', 107, 61, 141],
#  ['Emma', 'Cook', 29, 82, 252],
#  ['Ethan', 'Moore', 18, 64, 287],
#  ['Oliver', 'White', 23, 56, 270],
#  ['Ella', 'Thompson', 20, 63, 333],
#  ['Chloe', 'Sanders', 79, 62, 220],
#  ['Ava', 'Hayes', 57, 64, 233],
#  ['Isabella', 'Allen', 95, 74, 234],
#  ['Ella', 'Mitchell', 19, 66, 328],
#  ['Sophia', 'Torres', 73, 75, 237],
#  ['Isabella', 'Patterson', 94, 82, 313],
#  ['Mia', 'Peterson', 103, 67, 195],
#  ['Harper', 'Brown', 100, 59, 285],
#  ['Lucas', 'Cox', 102, 62, 143],
#  ['Sophia', 'Turner', 88, 66, 326],
#  ['Oliver', 'Gonzales', 76, 66, 246],
#  ['Mia', 'Williams', 42, 72, 122],
#  ['Ava', 'Parker', 19, 82, 190],
#  ['Liam', 'Sanchez', 86, 70, 285],
#  ['Mia', 'Jenkins', 54, 69, 346],
#  ['Sebastian', 'Coleman', 110, 61, 239],
#  ['Isabella', 'Lewis', 37, 71, 213],
#  ['Ethan', 'Griffin', 77, 55, 102],
#  ['Abigail', 'Murphy', 42, 54, 165],
#  ['Olivia', 'Flores', 52, 84, 211],
# ...

# %%
# create new dataframe from the new_records list of lists 

new_records_df = pd.DataFrame(new_records, columns=['first_name', 'last_name', 'age', 'height_inches', 'weight_lbs'])
new_records_df.head()
# Out:
#   first_name last_name  age  height_inches  weight_lbs
# 0        Mia    Miller   38             58         186
# 1      Avery   Roberts  107             61         141
# 2       Emma      Cook   29             82         252
# 3      Ethan     Moore   18             64         287
# 4     Oliver     White   23             56         270

# %%
patients_df.append(new_records_df, ignore_index = True)
# Out:
# /var/folders/4f/nyhvlyfd511911zdvn0fq0_00000gn/T/ipykernel_12702/1415544176.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   patients_df.append(new_records_df, ignore_index = True)
#     first_name last_name  age  height_inches  weight_lbs
# 0          Ava   Edwards   86             71         185
# 1          Mia    Miller   38             58         186
# 2        Avery   Roberts  107             61         141
# 3         Emma      Cook   29             82         252
# 4        Ethan     Moore   18             64         287
# ..         ...       ...  ...            ...         ...
# 96       Chloe    Butler   55             83         147
# 97        Lily    Harris   54             75         264
# 98        Emma     Young   83             54         291
# 99    Isabella  Robinson   77             61         206
# 100       Lily    Torres  102             83         211
#
# ...

# %%
patients_df = pd.concat([patients_df, new_records_df], ignore_index= True)

# %%
patients_df
# Out:
#     first_name last_name  age  height_inches  weight_lbs
# 0          Ava   Edwards   86             71         185
# 1          Mia    Miller   38             58         186
# 2        Avery   Roberts  107             61         141
# 3         Emma      Cook   29             82         252
# 4        Ethan     Moore   18             64         287
# ..         ...       ...  ...            ...         ...
# 96       Chloe    Butler   55             83         147
# 97        Lily    Harris   54             75         264
# 98        Emma     Young   83             54         291
# 99    Isabella  Robinson   77             61         206
# 100       Lily    Torres  102             83         211
#
# [101 rows x 5 columns]

# %%
# function to generate n records and return a new dataframe with the new records

def batch_new_records(n):
    # generate list of lists from gene
    new_records = []

    for i in range(n):
            new_patient = generate_patient_record(first_names_source, last_names_source)
            new_records.append(new_patient)

    new_records = pd.DataFrame(new_records, columns=['first_name', 'last_name', 'age', 'height_inches', 'weight_lbs'])

    return new_records

# %%
# testing function
batch_new_records(10)
# Out:
#   first_name last_name  age  height_inches  weight_lbs
# 0      Avery    Brooks   42             66         119
# 1  Charlotte     Davis   54             58         221
# 2   Benjamin  Gonzales   31             58         131
# 3       Emma  Campbell   88             73         104
# 4       Liam  Peterson   63             63         192
# 5      Chloe   Collins   24             57         230
# 6  Alexander   Jackson   93             75         183
# 7      Lucas  Anderson  103             60         345
# 8      James       Lee   71             58         324
# 9     Sophia    Garcia   18             59         301

# %%
# importing my .py file as module
# it contains source data lists for names and state abbreviates as well as all necessary functions to generate a dataframe

import random_dataframe as rd

# %%
# testing main function from module
patients_df = rd.batch_new_records(100)

patients_df.head()
# Out:
#   first_name  last_name  age  height_inches  weight_lbs state_residence
# 0      Aiden    Roberts   22             57         137              IA
# 1       Emma       Cook   43             75         203              AR
# 2        Mia   Robinson   32             68         278              CO
# 3    Abigail  Patterson   23             65         212              IN
# 4     Harper     Wright   73             64         271              GA

# %%
# creating more records to add to the original dataframe
additional_patients_df = rd.batch_new_records(5)

# %%
# pd.append is deprecated, use pd.concat

patients_df = pd.concat([patients_df, additional_patients_df], ignore_index= True)

# %%
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   first_name       105 non-null    object
#  1   last_name        105 non-null    object
#  2   age              105 non-null    int64
#  3   height_inches    105 non-null    int64
#  4   weight_lbs       105 non-null    int64
#  5   state_residence  105 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 5.0+ KB

# %%
patients_df['first_name'] = patients_df['first_name'].astype(str)

# %%
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   first_name       105 non-null    object
#  1   last_name        105 non-null    object
#  2   age              105 non-null    int64
#  3   height_inches    105 non-null    int64
#  4   weight_lbs       105 non-null    int64
#  5   state_residence  105 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 5.0+ KB

# %%
#manually add a single patient to dataframe using a dictionary
new_entry = {'first_name': 'Kelly',
             'last_name': 'Rodriguez',
             'age': 29,
             'height_inches': 64,
             'weight_lbs': 140,
             'state_residence': 'TX'}

new_entry_df = pd.DataFrame([new_entry])

patients_df = pd.concat([patients_df, new_entry_df], ignore_index= True)

# checking end of df to make sure it was added
patients_df.tail()
# Out:
#     first_name  last_name  age  height_inches  weight_lbs state_residence
# 101        Ava    Jackson   96             81         182              MO
# 102       Ella      Kelly   96             70         133              IA
# 103        Mia      Clark  107             67         302              NC
# 104       Liam     Hughes   96             62         255              KS
# 105      Kelly  Rodriguez   29             64         140              TX

# %%
# manually add a single new patient using a list

new_entry = ['Mark', 'Robinson', 34, 72, 220, 'NY']

patients_df.loc[len(patients_df)] = new_entry

#checking tail to make sure it was added
patients_df.tail()
# Out:
#     first_name  last_name  age  height_inches  weight_lbs state_residence
# 102       Ella      Kelly   96             70         133              IA
# 103        Mia      Clark  107             67         302              NC
# 104       Liam     Hughes   96             62         255              KS
# 105      Kelly  Rodriguez   29             64         140              TX
# 106       Mark   Robinson   34             72         220              NY
